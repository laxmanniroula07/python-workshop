# %%
import pandas as pd 
df = pd.read_csv("C:/Users/Admin/Documents/Downloads/sal - Sheet1.csv")
df.head()
# Out:
#    Experience  salary
# 0           5   35000
# 1           9   40000
# 2           4   20000
# 3           8   38000
# 4           7   36000

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
plt.scatter(df['Experience'],df['salary'])

# %%
x = df[['Experience']]
y=df[['salary']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#    Experience
# 0           5
# 1           9
# 6           7
# 8           2
# 3           8
# 2           4
# 5           8

# %%
y_train
# Out:
#    salary
# 0   35000
# 1   40000
# 6   32000
# 8   18000
# 3   38000
# 2   20000
# 5   37500

# %%
from sklearn.linear_model import LinearRegression
clf=LinearRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
clf.predict(x_test)
# Out:
# array([[31042.27941176],
#        [34246.32352941]])

# %%
y_test
# Out:
#    salary
# 7   34000
# 4   36000

# %%
clf.score(x_test,y_test)
# Out:
# -4.911746120782874
