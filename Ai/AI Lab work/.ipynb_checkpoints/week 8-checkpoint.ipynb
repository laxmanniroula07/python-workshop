# %% [markdown]
# Excercise : 2

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install NumPy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Excercise : 3

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
random_state_value = 42
# Generate random data for clustering
np.random.seed(random_state_value)
data, _ = make_blobs(n_samples=300, centers=3, cluster_std=1.0,random_state=42)

# Function to perform K-means clustering and plot the results
def plot_kmeans_clusters(data, n_clusters):
    kmeans = KMeans(n_clusters=n_clusters, random_state=random_state_value)
    labels = kmeans.fit_predict(data)
    
    plt.scatter(data[:, 0], data[:, 1], c=labels, cmap='viridis',edgecolor='k', s=50)
    plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1],
c='red', marker='x', s=200, label='Centroids')
    plt.title(f'K-means Clustering with {n_clusters} Clusters')
    plt.legend()
    plt.show()
    
plot_kmeans_clusters(data, n_clusters=2)

# %%
#Exercise 4: Read the script and understand how it works

# %% [markdown]
# Excercise : 5

# %%
# Loop through different cluster numbers from 2 to 10 and plot the results
for n_clusters in range(2, 11):
    plot_kmeans_clusters(data, n_clusters)

# %% [markdown]
# Excercise : 6

# %%
# Loop through different random state values and plot the resul.

# Generate random data for clustering
data, _ = make_blobs(n_samples=300, centers=3, cluster_std=1.0, random_state=42)

# Function to perform K-means clustering and plot the results
def plot_kmeans_clusters(data, n_clusters, random_state_value):
    kmeans = KMeans(n_clusters=n_clusters, random_state=random_state_value)
    labels = kmeans.fit_predict(data)
    
    plt.scatter(data[:, 0], data[:, 1], c=labels, cmap='viridis', edgecolor='k', s=50)
    plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], c='red', marker='x', s=200, label='Centroids')
    plt.title(f'K-means Clustering with {n_clusters} Clusters\nRandom State: {random_state_value}')
    plt.legend()
    plt.show()

# Different random state values to experiment with
random_state_values = [0, 42, 100, 2024]

# Number of clusters for comparison
n_clusters = 3

# Loop through different random state values and plot the results
for random_state in random_state_values:
    plot_kmeans_clusters(data, n_clusters, random_state)

# %% [markdown]
# Excercise : 7

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans

random_state_value = 42

# Load the Iris dataset
iris = load_iris()
data = iris.data

# Function to perform K-means clustering and plot the results
def plot_kmeans_clusters(data, n_clusters):
    kmeans = KMeans(n_clusters=n_clusters, random_state=random_state_value)
    labels = kmeans.fit_predict(data)
    
    plt.scatter(data[:, 0], data[:, 1], c=labels, cmap='viridis', edgecolor='k', s=50)
    plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], c='red', marker='x', s=200, label='Centroids')
    plt.title(f'K-means Clustering with {n_clusters} Clusters')
    plt.legend()
    plt.show()

# Plot the data with different numbers of clusters
N = [2, 3, 4, 5, 6, 7]
for n in N:
    plot_kmeans_clusters(data, n_clusters=n)
