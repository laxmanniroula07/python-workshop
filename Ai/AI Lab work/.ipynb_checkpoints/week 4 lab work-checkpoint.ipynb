# %%
# Exercise 1 Solution

#
coin_denominations = [1, 2, 5, 10, 20, 50, 100, 200]


target_amount = 93

min_coins = 0
coins_used = []


coin_denominations.sort(reverse=True)


for coin in coin_denominations:
    while target_amount >= coin:
        target_amount -= coin
        min_coins += 1
        coins_used.append(coin)

print(f"Minimum number of coins required: {min_coins}")
print("Coins used:", coins_used)
# Out:
# Minimum number of coins required: 5
# Coins used: [50, 20, 20, 2, 1]

# %%
# Define the coin denominations
coins = [200, 100, 50, 20, 10, 5, 2, 1]

# Target amount in pence
target = 93

# Calculate the minimum number of coins
def min_coins(coins, target):
    count = 0
    for coin in coins:
        while target >= coin:
            target -= coin
            count += 1
    return count

# Get the result for the target amount
min_coins_93p = min_coins(coins, target)
min_coins_93p
# Out:
# 5

# %%
# Exercise 1 Solution
coin_denominations = [1, 2, 5, 10, 20, 50, 100, 200]
target_amount = 93
min_coins = 0
coins_used = []
coin_denominations.sort(reverse=True)

for coin in coin_denominations:
    while target_amount >= coin:
        target_amount -= coin
        min_coins += 1
        coins_used.append(coin)

print("required of minimun coins: {min_coins}")
print("Coins used:", coins_used)
# Out:
# required of minimun coins: {min_coins}
# Coins used: [50, 20, 20, 2, 1]

# %%
# Exercise 3: Use the following python script to solve the problem.

def coin_change(coins, amount):
    coins.sort(reverse=True)  # Sort the coins in descending order
    coin_count = 0  # Variable to keep track of the total number of coins used
    change = []  # List to store the coins used
    for coin in coins:
        while amount >= coin:
            amount -= coin
            coin_count += 1
            change.append(coin)
    if amount == 0:
        print(f"Minimum number of coins required: {coin_count}")
        print("Coins used:", change)
    else:
        print("Not possible to get the desired change with the given coins.")

coins = [1, 2, 5, 10, 20, 50, 100, 200]  # List of available coins
amount = 93  # Amount for which we need to find the minimum number of coins
coin_change(coins, amount)
# Out:
# Minimum number of coins required: 5
# Coins used: [50, 20, 20, 2, 1]

# %%
def coin_change(coins, amount):
    coins.sort(reverse=True)  # Sort the coins in descending order
    coin_count = 0  # Variable to keep track of the total number of coins used
    change = []  # List to store the coins used
    for coin in coins:
        while amount >= coin:
            amount -= coin
            coin_count += 1
            change.append(coin)
    if amount == 0:
        print(f"Minimum number of coins required: {coin_count}")
        print("Coins used:", change)
    else:
        print("Not possible to get the desired change with the given coins.")


# Experiment  Coins [1, 10, 50], Sum Amounts 24, 68, 92
coins3 = [1, 10, 50]
amount3_1 = 24
amount3_2 = 68
amount3_3 = 92
coin_change(coins3, amount3_1)
coin_change(coins3, amount3_2)
coin_change(coins3, amount3_3)
# Out:
# Minimum number of coins required: 6
# Coins used: [10, 10, 1, 1, 1, 1]
# Minimum number of coins required: 10
# Coins used: [50, 10, 1, 1, 1, 1, 1, 1, 1, 1]
# Minimum number of coins required: 7
# Coins used: [50, 10, 10, 10, 10, 1, 1]

# %%
pip install networkx
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#exercise 7 A.

import heapq
import matplotlib.pyplot as plt
import networkx as nx

# Class representing a node in the graph
class Node:
    def __init__(self, name, heuristic_cost):
        self.name = name
        self.heuristic_cost = heuristic_cost
        self.adjacent = {}
        self.parent = None
        self.g_cost = float("inf")
    
    def add_neighbor(self, neighbor, cost):
        self.adjacent[neighbor] = cost
    
    def __lt__(self, other):
        return self.g_cost + self.heuristic_cost < other.g_cost + other.heuristic_cost

# %%
class Node:
    def __init__(self, name, heuristic_cost):
        self.name = name  # Name or identifier of the node
        self.heuristic_cost = heuristic_cost  # Heuristic cost for the node
        self.adjacent = {}  # Dictionary to store adjacent nodes and their edge costs
        self.parent = None  # Parent node in a path (used in search algorithms)
        self.g_cost = float("inf")  # Cost from start node to this node (used in search algorithms)

    def add_neighbor(self, neighbor, cost):
        """
        Add a neighbor to the node with the given cost.
        """
        self.adjacent[neighbor] = cost

    def __lt__(self, other):
        """
        Compare nodes based on their total cost (g_cost + heuristic_cost).
        """
        return self.g_cost + self.heuristic_cost < other.g_cost + other.heuristic_cost

# %%
# A* search algorithm
def astar_search(start, goal):
    open_list = []
    closed_set = set()
    start.g_cost = 0
    heapq.heappush(open_list, start)

    while open_list:
        current_node = heapq.heappop(open_list)

        if current_node == goal:
            path = []
            while current_node is not None:
                path.append(current_node.name)
                current_node = current_node.parent
            return path[::-1]

        closed_set.add(current_node)

        for neighbor, cost in current_node.adjacent.items():
            tentative_g_cost = current_node.g_cost + cost

            if neighbor in closed_set and tentative_g_cost >= neighbor.g_cost:
                continue

            if tentative_g_cost < neighbor.g_cost or neighbor not in open_list:
                neighbor.g_cost = tentative_g_cost
                neighbor.parent = current_node
                if neighbor not in open_list:
                    heapq.heappush(open_list, neighbor)

    return None

# %%
# Creating nodes
A = Node("A", 5)
B = Node("B", 4)
C = Node("C", 3)
D = Node("D", 2)
E = Node("E", 1)
F = Node("F", 0)

# Adding neighbors and their costs
A.add_neighbor(B, 1)
A.add_neighbor(C, 2)
B.add_neighbor(D, 5)
C.add_neighbor(D, 2)
C.add_neighbor(E, 4)
D.add_neighbor(F, 3)
E.add_neighbor(F, 2)

# Visualization without the solution
G = nx.Graph()
edges = [
    (A.name, B.name, {'weight': 1}),
    (A.name, C.name, {'weight': 2}),
    (B.name, D.name, {'weight': 5}),
    (C.name, D.name, {'weight': 2}),
    (C.name, E.name, {'weight': 4}),
    (D.name, F.name, {'weight': 3}),
    (E.name, F.name, {'weight': 2})
]
G.add_edges_from(edges)
pos = nx.spring_layout(G)
nx.draw_networkx(G, pos, with_labels=True, node_size=3000, node_color='skyblue')
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
plt.title('Nodes Graph')
plt.show()

# %%
# Visualization with A* path
plt.title('Graph with A* path')
nx.draw_networkx(G, pos, with_labels=True, node_size=3000,
node_color='skyblue')
nx.draw_networkx_edges(G, pos, edgelist=[(path[i], path[i + 1]) for i in
range(len(path) - 1)], edge_color='r', width=2)
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 6
#       2 plt.title('Graph with A* path')
#       3 nx.draw_networkx(G, pos, with_labels=True, node_size=3000,
#       4 node_color='skyblue')
#       5 nx.draw_networkx_edges(G, pos, edgelist=[(path[i], path[i + 1]) for i in
# ----> 6 range(len(path) - 1)], edge_color='r', width=2)
#       7 nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
#       8 plt.show()
#
# NameError: name 'path' is not defined

# %%
import heapq
import networkx as nx
import matplotlib.pyplot as plt
class Node:
    def __init__(self, name, h_cost):
        self.name = name
        self.h_cost = h_cost
        self.g_cost = float('inf')
        self.parent = None
        self.adjacent = {}
    def add_neighbor(self, neighbor, cost):
        self.adjacent[neighbor] = cost
    def __lt__(self, other):
        return (self.g_cost + self.h_cost) < (other.g_cost + other.h_cost)

# A* search algorithm
def astar_search(start, goal):
    open_list = []
    closed_set = set()
    start.g_cost = 0
    heapq.heappush(open_list, start)

    while open_list:
        current_node = heapq.heappop(open_list)

        if current_node == goal:
            path = []
            while current_node is not None:
                path.append(current_node.name)
                current_node = current_node.parent
            return path[::-1]

        closed_set.add(current_node)

        for neighbor, cost in current_node.adjacent.items():
            tentative_g_cost = current_node.g_cost + cost

            if neighbor in closed_set and tentative_g_cost >= neighbor.g_cost:
                continue

            if tentative_g_cost < neighbor.g_cost or neighbor not in open_list:
                neighbor.g_cost = tentative_g_cost
                neighbor.parent = current_node
                if neighbor not in open_list:
                    heapq.heappush(open_list, neighbor)

    return None



# Creating nodes with heuristic values (h_cost is estimated for demonstration)
Sunderland = Node("Sunderland", 10)
Newcastle = Node("Newcastle", 8)
Durham = Node("Durham", 6)
Middlesbrough = Node("Middlesbrough", 4)
Hartlepool = Node("Hartlepool", 5)
Washington = Node("Washington", 0)

# Adding neighbors and their costs (distances)
Sunderland.add_neighbor(Newcastle, 12)
Sunderland.add_neighbor(Durham, 20)
Newcastle.add_neighbor(Durham, 10)
Newcastle.add_neighbor(Washington, 15)
Durham.add_neighbor(Middlesbrough, 25)
Durham.add_neighbor(Hartlepool, 15)
Middlesbrough.add_neighbor(Washington, 30)
Hartlepool.add_neighbor(Washington, 20)

# Visualization without the solution
G = nx.Graph()
edges = [
    (Sunderland.name, Newcastle.name, {'weight': 12}),
    (Sunderland.name, Durham.name, {'weight': 20}),
    (Newcastle.name, Durham.name, {'weight': 10}),
    (Newcastle.name, Washington.name, {'weight': 15}),
    (Durham.name, Middlesbrough.name, {'weight': 25}),
    (Durham.name, Hartlepool.name, {'weight': 15}),
    (Middlesbrough.name, Washington.name, {'weight': 30}),
    (Hartlepool.name, Washington.name, {'weight': 20})
]
G.add_edges_from(edges)
pos = nx.spring_layout(G)
nx.draw_networkx(G, pos, with_labels=True, node_size=3000, node_color='skyblue')
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
plt.title('Nodes Graph')
plt.show()

# Running the A* search algorithm
path = astar_search(Sunderland, Washington)
print("A* path:", path)
# Out:
# A* path: ['Sunderland', 'Newcastle', 'Washington']

# %%
9

# %%
import heapq
import matplotlib.pyplot as plt
import networkx as nx

class Node:
    def __init__(self, name, h_cost):
        self.name = name
        self.h_cost = h_cost
        self.g_cost = float('inf')
        self.f_cost = float('inf')
        self.parent = None
        self.adjacent = {}

    def add_neighbor(self, neighbor, cost):
        self.adjacent[neighbor] = cost

    def __lt__(self, other):
        return self.f_cost < other.f_cost

def astar_search(start, goal):
    open_list = []
    closed_set = set()
    start.g_cost = 0
    start.f_cost = start.h_cost
    heapq.heappush(open_list, start)

    while open_list:
        current_node = heapq.heappop(open_list)
        if current_node == goal:
            path = []
            while current_node is not None:
                path.append(current_node.name)
                current_node = current_node.parent
            return path[::-1]

        closed_set.add(current_node)

        for neighbor, cost in current_node.adjacent.items():
            if neighbor in closed_set:
                continue
            tentative_g_cost = current_node.g_cost + cost

            if tentative_g_cost < neighbor.g_cost:
                neighbor.g_cost = tentative_g_cost
                neighbor.f_cost = neighbor.g_cost + neighbor.h_cost
                neighbor.parent = current_node
                if neighbor not in open_list:
                    heapq.heappush(open_list, neighbor)

    return None

# Creating nodes with heuristic costs (estimated straight-line distances to Washington)
Sunderland = Node("Sunderland", 12)
Newcastle = Node("Newcastle", 8)
Gateshead = Node("Gateshead", 4)
Washington = Node("Washington", 0)
Durham = Node("Durham", 10)

# Adding neighbors and their costs (actual driving distances)
Sunderland.add_neighbor(Newcastle, 26)
Sunderland.add_neighbor(Durham, 24)
Newcastle.add_neighbor(Gateshead, 4.5)
Newcastle.add_neighbor(Durham, 30)
Gateshead.add_neighbor(Washington, 12)
Durham.add_neighbor(Washington, 16)

# Visualization without the solution
G = nx.Graph()
edges = [
    (Sunderland.name, Newcastle.name, {'weight': 26}),
    (Sunderland.name, Durham.name, {'weight': 24}),
    (Newcastle.name, Gateshead.name, {'weight': 4.5}),
    (Newcastle.name, Durham.name, {'weight': 30}),
    (Gateshead.name, Washington.name, {'weight': 12}),
    (Durham.name, Washington.name, {'weight': 16})
]
G.add_edges_from(edges)
pos = nx.spring_layout(G)
nx.draw_networkx(G, pos, with_labels=True, node_size=3000, node_color='skyblue')
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
plt.title('Nodes Graph')
plt.show()

# Running the A* search algorithm
path = astar_search(Sunderland, Washington)
print("A* path:", path)
# Out:
# A* path: ['Sunderland', 'Durham', 'Washington']

# %%
#3x10

# Visualization without the solution
G = nx.Graph()
edges = [
    (Sunderland.name, Newcastle.name, {'weight': 12}),
    (Sunderland.name, Durham.name, {'weight': 20}),
    (Newcastle.name, Durham.name, {'weight': 10}),
    (Newcastle.name, Washington.name, {'weight': 15}),
    (Durham.name, Middlesbrough.name, {'weight': 25}),
    (Durham.name, Hartlepool.name, {'weight': 15}),
    (Middlesbrough.name, Washington.name, {'weight': 30}),
    (Hartlepool.name, Washington.name, {'weight': 20})
]
G.add_edges_from(edges)
pos = nx.spring_layout(G)
nx.draw_networkx(G, pos, with_labels=True, node_size=3000, node_color='skyblue')
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
plt.title('Nodes Graph')
plt.show()

# Function to run A* search and measure duration
def run_astar_search(start, goal):
    # Reset nodes' g_cost and parent
    for node in [Sunderland, Newcastle, Durham, Middlesbrough, Hartlepool, Washington]:
        node.g_cost = float('inf')
        node.parent = None
    
    # Measure the duration to find the path
    start_time = time.time()
    path = astar_search(start, goal)
    end_time = time.time()
    
    # Calculate the duration
    duration = end_time - start_time
    return path, duration

# Experiment with different starting and ending points
experiments = [
    (Sunderland, Washington),
    (Newcastle, Middlesbrough),
    (Durham, Hartlepool)
]

for start, goal in experiments:
    path, duration = run_astar_search(start, goal)
    print(f"A* path from {start.name} to {goal.name}: {path}, Duration: {duration:.6f} seconds")

# Function to run A* search and measure duration
def run_astar_search(start, goal):
    # Reset nodes' g_cost and parent
    for node in [Sunderland, Newcastle, Durham, Middlesbrough, Hartlepool, Washington]:
        node.g_cost = float('inf')
        node.parent = None
    
    # Measure the duration to find the path
    start_time = time.time()
    path = astar_search(start, goal)
    end_time = time.time()
    
    # Calculate the duration
    duration = end_time - start_time
    return path, duration

# Experiment with different starting and ending points
experiments = [
    (Sunderland, Washington),
    (Newcastle, Middlesbrough),
    (Durham, Hartlepool)
]

for start, goal in experiments:
    path, duration = run_astar_search(start, goal)
    print(f"A* path from {start.name} to {goal.name}: {path}, Duration: {duration:.6f} seconds")
# Out:
# A* path from Sunderland to Washington: ['Sunderland', 'Newcastle', 'Washington'], Duration: 0.000000 seconds
# A* path from Newcastle to Middlesbrough: ['Newcastle', 'Durham', 'Middlesbrough'], Duration: 0.000000 seconds
# A* path from Durham to Hartlepool: ['Durham', 'Hartlepool'], Duration: 0.000000 seconds
# A* path from Sunderland to Washington: ['Sunderland', 'Newcastle', 'Washington'], Duration: 0.000000 seconds
# A* path from Newcastle to Middlesbrough: ['Newcastle', 'Durham', 'Middlesbrough'], Duration: 0.000000 seconds
# A* path from Durham to Hartlepool: ['Durham', 'Hartlepool'], Duration: 0.000000 seconds

# %%
#ex11
import random

# Number of individuals in each generation
POPULATION_SIZE = 4

# Valid genes
GENES = '''01'''

# Target string to be generated
TARGET = "001010"

class Individual:
    # Class representing individual in population
    def __init__(self, chromosome):
        self.chromosome = chromosome
        self.fitness = self.cal_fitness()

    @classmethod
    def mutated_genes(cls):
        # Create random genes for mutation
        gene = random.choice(GENES)
        return gene

    @classmethod
    def create_gnome(cls):
        # Create chromosome or string of genes
        gnome_len = len(TARGET)
        return [cls.mutated_genes() for _ in range(gnome_len)]

    def mate(self, par2):
        # Perform mating and produce new offspring
        # chromosome for offspring
        child_chromosome = []
        for gp1, gp2 in zip(self.chromosome, par2.chromosome):
            # random probability
            prob = random.random()
            # if prob is less than 0.45, insert gene from parent 1
            if prob < 0.45:
                child_chromosome.append(gp1)
            # if prob is between 0.45 and 0.90, insert gene from parent 2
            elif prob < 0.90:
                child_chromosome.append(gp2)
            # otherwise insert random gene (mutate),
            # for maintaining diversity
            else:
                child_chromosome.append(self.mutated_genes())
        # create new Individual (offspring) using generated chromosome for offspring
        return Individual(child_chromosome)

    def cal_fitness(self):
        ''' Calculate fitness score, it is the number of characters in string
        which differ from target string. '''
        global TARGET
        fitness = 0
        for gs, gt in zip(self.chromosome, TARGET):
            if gs != gt:
                fitness += 1
        return fitness


# Driver code
def main():
    global POPULATION_SIZE

    # current generation
    generation = 1

    found = False
    population = []

    # create initial population
    for _ in range(POPULATION_SIZE):
        gnome = Individual.create_gnome()
        population.append(Individual(gnome))

    while not found:
        # sort the population in increasing order of fitness score
        population = sorted(population, key=lambda x: x.fitness)

        # if the individual having lowest fitness score ie.
        # 0 then we know that we have reached the target
        # and break the loop
        if population[0].fitness <= 0:
            found = True
            break

        # Otherwise generate new offsprings for new generation
        new_generation = []

        # Perform Elitism, that means 10% of the fittest population
        # goes to the next generation
        s = int((10 * POPULATION_SIZE) / 100)
        new_generation.extend(population[:s])

        # From 50% of the fittest population, Individuals
        # will mate to produce offspring
        s = int((90 * POPULATION_SIZE) / 100)
        for _ in range(s):
            parent1 = random.choice(population[:50])
            parent2 = random.choice(population[:50])
            child = parent1.mate(parent2)
            new_generation.append(child)

        population = new_generation

        print("Generation: {}\tString: {}\tFitness: {}".format(
            generation, "".join(population[0].chromosome), population[0].fitness))

        generation += 1

    print("Generation: {}\tString: {}\tFitness: {}".format(
        generation, "".join(population[0].chromosome), population[0].fitness))


if __name__ == '__main__':
    main()
# Out:
# Generation: 1	String: 111000	Fitness: 3
# Generation: 2	String: 111000	Fitness: 3
# Generation: 3	String: 110000	Fitness: 4
# Generation: 4	String: 110000	Fitness: 4
# Generation: 5	String: 100000	Fitness: 3
# Generation: 6	String: 100010	Fitness: 2
# Generation: 7	String: 000001	Fitness: 3
# Generation: 8	String: 100010	Fitness: 2
# Generation: 9	String: 100010	Fitness: 2
# Generation: 10	String: 100010	Fitness: 2
# Generation: 11	String: 000000	Fitness: 2
# Generation: 12	String: 000000	Fitness: 2
# Generation: 13	String: 000000	Fitness: 2
# Generation: 14	String: 000000	Fitness: 2
# Generation: 15	String: 100010	Fitness: 2
# Generation: 16	String: 100000	Fitness: 3
# Generation: 17	String: 100000	Fitness: 3
# Generation: 18	String: 100000	Fitness: 3
# Generation: 19	String: 100000	Fitness: 3
# Generation: 20	String: 100000	Fitness: 3
# Generation: 21	String: 100000	Fitness: 3
# Generation: 22	String: 100000	Fitness: 3
# Generation: 23	String: 100000	Fitness: 3
# ...

# %%
# ex 12 


# Creating nodes for the letters in "WELCOME TO AI"
letters = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
nodes = {letter: Node(letter, 0) for letter in letters}

# Defining the phrase we want to spell out
phrase = "WELCOME TO AI"

# Connecting nodes based on the phrase
for i in range(len(phrase) - 1):
    if phrase[i] != ' ' and phrase[i+1] != ' ':
        nodes[phrase[i]].add_neighbor(nodes[phrase[i+1]], 1)

# Visualization without the solution
G = nx.Graph()
edges = [(phrase[i], phrase[i+1], {'weight': 1}) for i in range(len(phrase) - 1) if phrase[i] != ' ' and phrase[i+1] != ' ']
G.add_edges_from(edges)
pos = nx.spring_layout(G)
nx.draw_networkx(G, pos, with_labels=True, node_size=3000, node_color='skyblue')
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
plt.title('WELCOME TO AI Graph')
plt.show()

# Running the A* search algorithm
start = nodes[phrase[0]]
goal = nodes[phrase[-1]]
path = astar_search(start, goal)
print("A* path:", path)
# Out:
# A* path: None

# %%
#ex 13


# Defining the phrase we want to spell out
phrase = "WELCOME TO AI"

# Connecting nodes based on the phrase
for i in range(len(phrase) - 1):
    if phrase[i] != ' ' and phrase[i+1] != ' ':
        nodes[phrase[i]].add_neighbor(nodes[phrase[i+1]], 1)

# Visualization without the solution
G = nx.Graph()
edges = [(phrase[i], phrase[i+1], {'weight': 1}) for i in range(len(phrase) - 1) if phrase[i] != ' ' and phrase[i+1] != ' ']
G.add_edges_from(edges)
pos = nx.spring_layout(G)
nx.draw_networkx(G, pos, with_labels=True, node_size=3000, node_color='skyblue')
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
plt.title('WELCOME TO AI Graph')
plt.show()

# Running the A* search algorithm and measuring the duration
start_time = time.time()

start = nodes[phrase[0]]
goal = nodes[phrase[-1]]
path = astar_search(start, goal)

end_time = time.time()
duration = end_time - start_time

print("A* path:", path)
print(f"Time taken to find the solution: {duration:.4f} seconds")
# Out:
# A* path: None
# Time taken to find the solution: 0.0010 seconds

# %%
#ex 14 



# Defining a new phrase with 5 words
phrase = "HELLO WORLD FROM AI AGENTS"

# Connecting nodes based on the phrase
for i in range(len(phrase) - 1):
    if phrase[i] != ' ' and phrase[i+1] != ' ':
        nodes[phrase[i]].add_neighbor(nodes[phrase[i+1]], 1)

# Visualization without the solution
G = nx.Graph()
edges = [(phrase[i], phrase[i+1], {'weight': 1}) for i in range(len(phrase) - 1) if phrase[i] != ' ' and phrase[i+1] != ' ']
G.add_edges_from(edges)
pos = nx.spring_layout(G)
nx.draw_networkx(G, pos, with_labels=True, node_size=3000, node_color='skyblue')
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
plt.title('HELLO WORLD FROM AI AGENTS Graph')
plt.show()

# Running the A* search algorithm and measuring the duration
start_time = time.time()

start = nodes[phrase[0]]
goal = nodes[phrase[-1]]
path = astar_search(start, goal)

end_time = time.time()
duration = end_time - start_time

print("A* path:", path)
print(f"Time taken to find the solution: {duration:.4f} seconds")
# Out:
# A* path: ['H', 'E', 'N', 'T', 'S']
# Time taken to find the solution: 0.0000 seconds

# %%
#ex 15 


# Creating nodes for letters and numbers
characters = "ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789"
nodes = {char: Node(char, 0) for char in characters}

# Defining a new phrase with letters and numbers
phrase = "HELLO AI 2024 WORLD"

# Connecting nodes based on the phrase
for i in range(len(phrase) - 1):
    if phrase[i] != ' ' and phrase[i+1] != ' ':
        nodes[phrase[i]].add_neighbor(nodes[phrase[i+1]], 1)

# Visualization without the solution
G = nx.Graph()
edges = [(phrase[i], phrase[i+1], {'weight': 1}) for i in range(len(phrase) - 1) if phrase[i] != ' ' and phrase[i+1] != ' ']
G.add_edges_from(edges)
pos = nx.spring_layout(G)
nx.draw_networkx(G, pos, with_labels=True, node_size=3000, node_color='skyblue')
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
plt.title('HELLO AI 2024 WORLD Graph')
plt.show()

# Running the A* search algorithm and measuring the duration
start_time = time.time()

start = nodes[phrase[0]]
goal = nodes[phrase[-1]]
path = astar_search(start, goal)

end_time = time.time()
duration = end_time - start_time

print("A* path:", path)
print(f"Time taken to find the solution: {duration:.4f} seconds")
# Out:
# A* path: ['H', 'E', 'L', 'D']
# Time taken to find the solution: 0.0000 seconds
