# %% [markdown]
# Exercise 1

# %%
from collections import deque
def bfs(graph, start, goal):
    visited = set()
    queue = deque([(start, [])])
    while queue:
        node, path = queue.popleft()
        if node == goal:
            return path + [node]
        if node not in visited:
            visited.add(node)
            for neighbor in graph[node]:
                queue.append((neighbor, path + [node]))
    return None
graph = {
    'A': ['B', 'C'],
    'B': ['A', 'D', 'E'],
    'C': ['A', 'F'],
    'D': ['B'],
    'E': ['B', 'F'],
    'F': ['C', 'E']
}
start_node = 'A'
goal_node = 'E'
result = bfs(graph, start_node, goal_node)
if result:
    print("Path found:", result)    
else:
    print("No path found.")
# Out:
# Path found: ['A', 'B', 'E']

# %%
#changing starting and ending point
from collections import deque
def bfs(graph, start, goal):
    visited = set()
    queue = deque([(start, [])])
    while queue:
        node, path = queue.popleft()
        if node == goal:
            return path + [node]
        if node not in visited:
            visited.add(node)
            for neighbor in graph[node]:
                queue.append((neighbor, path + [node]))
    return None
graph = {
    'A': ['B', 'C'],
    'B': ['A', 'D', 'E'],
    'C': ['A', 'F'],
    'D': ['B'],
    'E': ['B', 'F'],
    'F': ['C', 'E']
}
start_node = 'B'     # Changed starting point to 'B'
goal_node = 'F'      # Changed ending point to 'C'
result = bfs(graph, start_node, goal_node)
if result:
    print("Path found:", result)
else:
    print("No path found.")
# Out:
# Path found: ['B', 'E', 'F']

# %%
#Using time library to calculate how long would it take to solve the problem using three different starting points and ending points


from collections import deque
import time
def bfs(graph, start, goal):
    visited = set()
    queue = deque([(start, [])])
    while queue:
        node, path = queue.popleft()
        if node == goal:
            return path + [node]
        if node not in visited:
            visited.add(node)
            for neighbor in graph[node]:
                queue.append((neighbor, path + [node]))
    return None
graph = {
    'A': ['B', 'C'],
    'B': ['A', 'D', 'E'],
    'C': ['A', 'F'],
    'D': ['B'],
    'E': ['B', 'F'],
    'F': ['C', 'E']
}

# Define starting points and ending points for three different scenarios
scenarios = [
    ('A', 'F'),
    ('B', 'C'),
    ('C', 'E')
]

# Measure time for each scenario
for start_node, goal_node in scenarios:
    start_time = time.time()
    result = bfs(graph, start_node, goal_node)
    end_time = time.time()

    if result:
        print(f"Path found from {start_node} to {goal_node}: {result}")
    else:
        print(f"No path found from {start_node} to {goal_node}.")

    time_taken = end_time - start_time
    print(f"Time taken for scenario ({start_node}, {goal_node}): {time_taken} seconds\n")
# Out:
# Path found from A to F: ['A', 'C', 'F']
# Time taken for scenario (A, F): 0.0 seconds
#
# Path found from B to C: ['B', 'A', 'C']
# Time taken for scenario (B, C): 0.0 seconds
#
# Path found from C to E: ['C', 'F', 'E']
# Time taken for scenario (C, E): 0.0 seconds

# %%
#change scripts
from collections import deque
import time

def bfs(graph, start, goal):
    visited = set()
    queue = deque([(start, [])])
    while queue:
        node, path = queue.popleft()
        if node == goal:
            return path + [node]
        if node not in visited:
            visited.add(node)
            for neighbor in graph[node]:
                queue.append((neighbor, path + [node]))
    return None

# Define the new graph
graph = {
    'A': ['B', 'C'],
    'B': ['A', 'D', 'E'],
    'C': ['A', 'F'],
    'D': ['B', 'G'],
    'E': ['B', 'F'],
    'F': ['C', 'E'],
    'G': ['D', 'H'],
    'H': ['E', 'G']
}

# Define starting points and ending points for three different scenarios
scenarios = [
    ('A', 'G'),
    ('B', 'H'),
    ('C', 'D')
]

# Measure time for each scenario
for start_node, goal_node in scenarios:
    start_time = time.time()
    result = bfs(graph, start_node, goal_node)
    end_time = time.time()

    if result:
        print(f"Path found from {start_node} to {goal_node}: {result}")
    else:
        print(f"No path found from {start_node} to {goal_node}.")

    time_taken = end_time - start_time
    print(f"Time taken for scenario ({start_node}, {goal_node}): {time_taken} seconds\n")
# Out:
# Path found from A to G: ['A', 'B', 'D', 'G']
# Time taken for scenario (A, G): 0.0 seconds
#
# Path found from B to H: ['B', 'D', 'G', 'H']
# Time taken for scenario (B, H): 0.0 seconds
#
# Path found from C to D: ['C', 'A', 'B', 'D']
# Time taken for scenario (C, D): 0.0 seconds

# %%
#update script
from collections import deque
import time

def bfs(graph, start, goal):
    visited = set()
    queue = deque([(start, [])])
    while queue:
        node, path = queue.popleft()
        if node == goal:
            return path + [node]
        if node not in visited:
            visited.add(node)
            for neighbor in graph[node]:
                queue.append((neighbor, path + [node]))
    return None

# Define the new graph
graph = {
    'A': ['B', 'C'],
    'B': ['A', 'D', 'E'],
    'C': ['A', 'F'],
    'D': ['B', 'G'],
    'E': ['B', 'F', 'H'],
    'F': ['C', 'E'],
    'G': ['D', 'H'],
    'H': ['E', 'G']
}

# Define starting points and ending points for four different scenarios
scenarios = [
    ('A', 'H')
]

# Measure time for each scenario
for start_node, goal_node in scenarios:
    start_time = time.time()
    result = bfs(graph, start_node, goal_node)
    end_time = time.time()

    if result:
        print(f"Path found from {start_node} to {goal_node}: {result}")
    else:
        print(f"No path found from {start_node} to {goal_node}.")

    time_taken = end_time - start_time
    print(f"Time taken for scenario ({start_node}, {goal_node}): {time_taken} seconds\n")
# Out:
# Path found from A to H: ['A', 'B', 'E', 'H']
# Time taken for scenario (A, H): 0.0 seconds

# %% [markdown]
# Excerise 2

# %%
def dfs(graph, node, goal, visited=None):
    if visited is None:
        visited = set()
    if node == goal:
        return [node]
    if node not in visited:
        visited.add(node)
        for neighbor in graph[node]:
            path = dfs(graph, neighbor, goal, visited)
            if path:
                return [node] + path
    return None # Goal not found
# Example usage (same graph as before)
result = dfs(graph, start_node, goal_node)
if result:
    print("Path found:", result)
else:
    print("No path found.")
# Out:
# Path found: ['A', 'B', 'D', 'G', 'H']

# %%
def dfs(graph, node, goal, visited=None):
    if visited is None:
        visited = set()
    if node == goal:
        return [node]
    if node not in visited:
        visited.add(node)
        for neighbor in graph[node]:
            path = dfs(graph, neighbor, goal, visited)
            if path:
                return [node] + path
    return None # Goal not found

# Example graph
graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': [],
    'E': ['F'],
    'F': []
}

# Test with first set of start and goal nodes
start_node = 'A'
goal_node = 'F'
result = dfs(graph, start_node, goal_node)
if result:
    print("Path found from A to F:", result)
else:
    print("No path found from A to F.")
# Out:
# Path found from A to F: ['A', 'B', 'E', 'F']

# %%
import time

def dfs(graph, node, goal, visited=None):
    if visited is None:
        visited = set()
    if node == goal:
        return [node]
    if node not in visited:
        visited.add(node)
        for neighbor in graph[node]:
            path = dfs(graph, neighbor, goal, visited)
            if path:
                return [node] + path
    return None  # Goal not found

# Example graph
graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': [],
    'E': ['F'],
    'F': []
}

# Test with different sets of start and goal nodes
test_cases = [
    ('A', 'F'),
    ('B', 'F'),
    ('C', 'D')
]

for start_node, goal_node in test_cases:
    start_time = time.time()
    result = dfs(graph, start_node, goal_node)
    end_time = time.time()

    if result:
        print(f"Path found from {start_node} to {goal_node}: {result}")
    else:
        print(f"No path found from {start_node} to {goal_node}.")

    print(f"Time taken: {end_time - start_time:.6f} seconds\n")
# Out:
# Path found from A to F: ['A', 'B', 'E', 'F']
# Time taken: 0.000000 seconds
#
# Path found from B to F: ['B', 'E', 'F']
# Time taken: 0.000000 seconds
#
# No path found from C to D.
# Time taken: 0.000000 seconds

# %% [markdown]
# Exercise 3(I)

# %%
def dls(graph, node, goal, depth, visited=None):
    if visited is None:
        visited = set()
    if depth == 0:
        return None
    if node == goal:
        return [node]
    if node not in visited:
        visited.add(node)
        for neighbor in graph[node]:
            path = dls(graph, neighbor, goal, depth - 1, visited)
            if path:
                return [node] + path
    return None
# Example usage (same graph as before)
max_depth = 3
result = dls(graph, start_node, goal_node, max_depth)
if result:
    print("Path found:", result)
else:
    print("No path found.")
# Out:
# No path found.

# %%
def dls(graph, node, goal, depth, visited=None):
    if visited is None:
        visited = set()
    if depth == 0:
        return None
    if node == goal:
        return [node]
    if node not in visited:
        visited.add(node)
        for neighbor in graph[node]:
            path = dls(graph, neighbor, goal, depth - 1, visited)
            if path:
                return [node] + path
    return None

# Example graph (same as before)
graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': [],
    'E': ['F'],
    'F': []
}

# Test with different maximum depths
test_cases = [
    ('A', 'F', 3),
    ('A', 'F', 5),
    ('A', 'F', 7)
]

for start_node, goal_node, max_depth in test_cases:
    result = dls(graph, start_node, goal_node, max_depth)
    if result:
        print(f"Path found from {start_node} to {goal_node} with max depth {max_depth}: {result}")
    else:
        print(f"No path found from {start_node} to {goal_node} with max depth {max_depth}.")
# Out:
# Path found from A to F with max depth 3: ['A', 'C', 'F']
# Path found from A to F with max depth 5: ['A', 'B', 'E', 'F']
# Path found from A to F with max depth 7: ['A', 'B', 'E', 'F']

# %%
def dfs(graph, node, goal, visited=None):
    if visited is None:
        visited = set()
    if node == goal:
        return [node]
    if node not in visited:
        visited.add(node)
        for neighbor in graph[node]:
            path = dfs(graph, neighbor, goal, visited)
            if path:
                return [node] + path
    return None

def dls(graph, node, goal, depth, visited=None):
    if visited is None:
        visited = set()
    if depth == 0:
        return None
    if node == goal:
        return [node]
    if node not in visited:
        visited.add(node)
        for neighbor in graph[node]:
            path = dls(graph, neighbor, goal, depth - 1, visited)
            if path:
                return [node] + path
    return None

# Example graph with many layers
graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': ['G', 'H'],
    'E': ['I', 'J'],
    'F': ['K'],
    'G': ['L', 'M'],
    'H': ['N'],
    'I': ['O'],
    'J': ['P'],
    'K': ['Q'],
    'L': [],
    'M': [],
    'N': [],
    'O': [],
    'P': [],
    'Q': []
}

# Example usage and comparison of DFS and DLS
start_node = 'A'
goal_node = 'Q'
max_depth = 5

# DFS
result_dfs = dfs(graph, start_node, goal_node)
if result_dfs:
    print("DFS Path found:", result_dfs)
else:
    print("DFS No path found.")

# DLS
result_dls = dls(graph, start_node, goal_node, max_depth)
if result_dls:
    print(f"DLS Path found with max depth {max_depth}:", result_dls)
else:
    print(f"DLS No path found with max depth {max_depth}.")
# Out:
# DFS Path found: ['A', 'C', 'F', 'K', 'Q']
# DLS Path found with max depth 5: ['A', 'C', 'F', 'K', 'Q']

# %% [markdown]
# Exercisse 3(II)

# %%
from collections import deque

def bfs_maze(maze, start, goal):
    rows, cols = len(maze), len(maze[0])
    visited = set()
    parent = {} # To keep track of the parent of each cell in the path
    
    def is_valid(x, y):
        return 0 <= x < rows and 0 <= y < cols and maze[x][y] != '#' and (x, y
) not in visited


    queue = deque([start])
    visited.add(start)
    found = False
    
    while queue:
        x, y = queue.popleft()
        if (x, y) == goal: found = True; break
    # Define possible moves: up, down, left, right
        moves = [(0, 1), (1, 0), (0, -1), (-1, 0)]

        for dx, dy in moves:
            new_x, new_y = x + dx, y + dy
            if is_valid(new_x, new_y):
                queue.append((new_x, new_y))
                visited.add((new_x, new_y))
                parent[(new_x, new_y)] = (x, y)

    if not found: return "No path found"


    # Reconstruct the path from the goal to the start
    path = []
    x, y = goal
    while (x, y) != start:
        path.append((x, y))
        x, y = parent[(x, y)]
    path.append(start)
    path.reverse()
    
    # Update the maze with the path
    for x, y in path:
        if maze[x][y] != 'S' and maze[x][y] != 'G':
            maze[x][y] = '*'
    return "Path found"
# Define the corrected maze
maze = [
['S', '.', '.', '.', '.', '.', '#', '.', '.'],
['#', '#', '#', '#', '#', '.', '#', '#', '#'],
['.', '.', '.', '.', '.', '.', '.', '.', 'G'],
['#', '#', '#', '#', '#', '#', '#', '#', '#']
]

# Starting and goal positions
start_position = (0, 0)
goal_position = (2, 8)
result = bfs_maze(maze, start_position, goal_position)
# Print the maze with the path
for row in maze:

    print(' '.join(row))
print(result)
# Out:
# S * * * * * # . .
# # # # # # * # # #
# . . . . . * * * G
# # # # # # # # # #
# Path found

# %% [markdown]
# Exercise 4

# %%
def dfs_maze(maze, start, goal):
    rows, cols = len(maze), len(maze[0])
    visited = set()
    path = []  # Store the path
    
    def is_valid(x, y):
        return 0 <= x < rows and 0 <= y < cols and maze[x][y] != '#' and (x, y) not in visited
    
    def dfs(x, y):
        if x == goal[0] and y == goal[1]:
            return True
        
        visited.add((x, y))
        path.append((x, y))
        
        # Define possible moves: up, down, left, right
        moves = [(0, 1), (1, 0), (0, -1), (-1, 0)]
        for dx, dy in moves:
            new_x, new_y = x + dx, y + dy
            if is_valid(new_x, new_y):
                if dfs(new_x, new_y):
                    return True
        
        path.pop()  # Remove the current cell from the path if no valid moves
        return False
    
    if dfs(start[0], start[1]):
        # Update the maze with the path
        for x, y in path:
            if maze[x][y] != 'S' and maze[x][y] != 'G':
                maze[x][y] = '*'
        return "Path found"
    else:
        return "No path found"

# Define the corrected maze
maze = [
    ['S', '.', '.', '.', '.', '.', '#', '.', '.'],
    ['#', '#', '#', '#', '#', '.', '#', '#', '#'],
    ['.', '.', '.', '.', '.', '.', '.', '.', 'G'],
    ['#', '#', '#', '#', '#', '#', '#', '#', '#']
]

# Starting and goal positions
start_position = (0, 0)
goal_position = (2, 8)

# Solve the maze using DFS
result = dfs_maze(maze, start_position, goal_position)

# Print the maze with the path
for row in maze:
    print(' '.join(row))
print(result)
# Out:
# S * * * * * # . .
# # # # # # * # # #
# . . . . . * * * G
# # # # # # # # # #
# Path found

# %%
#Do comparison of both algorithms and find the time it takes to run them.
import time

def dfs_maze(maze, start, goal):
    rows, cols = len(maze), len(maze[0])
    visited = set()
    path = []  # Store the path
    
    def is_valid(x, y):
        return 0 <= x < rows and 0 <= y < cols and maze[x][y] != '#' and (x, y) not in visited
    
    def dfs(x, y):
        if x == goal[0] and y == goal[1]:
            return True
        
        visited.add((x, y))
        path.append((x, y))
        
        # Define possible moves: up, down, left, right
        moves = [(0, 1), (1, 0), (0, -1), (-1, 0)]
        for dx, dy in moves:
            new_x, new_y = x + dx, y + dy
            if is_valid(new_x, new_y):
                if dfs(new_x, new_y):
                    return True
        
        path.pop()  # Remove the current cell from the path if no valid moves
        return False
    
    if dfs(start[0], start[1]):
        # Update the maze with the path
        for x, y in path:
            if maze[x][y] != 'S' and maze[x][y] != 'G':
                maze[x][y] = '*'
        return "Path found"
    else:
        return "No path found"

def bfs_maze(maze, start, goal):
    rows, cols = len(maze), len(maze[0])
    queue = deque([start])
    visited = set([start])
    parent = {start: None}
    
    while queue:
        x, y = queue.popleft()
        
        if (x, y) == goal:
            break
        
        # Define possible moves: up, down, left, right
        moves = [(0, 1), (1, 0), (0, -1), (-1, 0)]
        for dx, dy in moves:
            new_x, new_y = x + dx, y + dy
            if 0 <= new_x < rows and 0 <= new_y < cols and maze[new_x][new_y] != '#' and (new_x, new_y) not in visited:
                queue.append((new_x, new_y))
                visited.add((new_x, new_y))
                parent[(new_x, new_y)] = (x, y)
    
    # Reconstruct the path
    if goal not in parent:
        return "No path found"
    
    path = []
    step = goal
    while step is not None:
        path.append(step)
        step = parent[step]
    
    path.reverse()
    
    # Update the maze with the path
    for x, y in path:
        if maze[x][y] != 'S' and maze[x][y] != 'G':
            maze[x][y] = '*'
    
    return "Path found"

# Define the corrected maze
maze = [
    ['S', '.', '.', '.', '.', '.', '#', '.', '.'],
    ['#', '#', '#', '#', '#', '.', '#', '#', '#'],
    ['.', '.', '.', '.', '.', '.', '.', '.', 'G'],
    ['#', '#', '#', '#', '#', '#', '#', '#', '#']
]

# Starting and goal positions
start_position = (0, 0)
goal_position = (2, 8)

# Measure time for DFS
start_time = time.time()
result_dfs = dfs_maze([row[:] for row in maze], start_position, goal_position)
end_time = time.time()
dfs_time = end_time - start_time

# Measure time for BFS
start_time = time.time()
result_bfs = bfs_maze([row[:] for row in maze], start_position, goal_position)
end_time = time.time()
bfs_time = end_time - start_time

# Print the maze with the path for DFS
print("DFS:")
for row in maze:
    print(' '.join(row))
print(result_dfs)
print(f"Time taken for DFS: {dfs_time:.6f} seconds\n")

# Print the maze with the path for BFS
print("BFS:")
for row in maze:
    print(' '.join(row))
print(result_bfs)
print(f"Time taken for BFS: {bfs_time:.6f} seconds")
# Out:
# DFS:
# S . . . . . # . .
# # # # # # . # # #
# . . . . . . . . G
# # # # # # # # # #
# Path found
# Time taken for DFS: 0.000000 seconds
#
# BFS:
# S . . . . . # . .
# # # # # # . # # #
# . . . . . . . . G
# # # # # # # # # #
# Path found
# Time taken for BFS: 0.000000 seconds

# %%
#Try different starting and ending points then calculate the number of steps needed to solve the problem.
def dfs_maze(maze, start, goal):
    rows, cols = len(maze), len(maze[0])
    visited = set()
    path = []  # Store the path
    
    def is_valid(x, y):
        return 0 <= x < rows and 0 <= y < cols and maze[x][y] != '#' and (x, y) not in visited
    
    def dfs(x, y):
        if x == goal[0] and y == goal[1]:
            return True
        
        visited.add((x, y))
        path.append((x, y))
        
        # Define possible moves: up, down, left, right
        moves = [(0, 1), (1, 0), (0, -1), (-1, 0)]
        for dx, dy in moves:
            new_x, new_y = x + dx, y + dy
            if is_valid(new_x, new_y):
                if dfs(new_x, new_y):
                    return True
        
        path.pop()  # Remove the current cell from the path if no valid moves
        return False
    
    if dfs(start[0], start[1]):
        # Update the maze with the path
        for x, y in path:
            if maze[x][y] != 'S' and maze[x][y] != 'G':
                maze[x][y] = '*'
        return "Path found"
    else:
        return "No path found"

# Define the corrected maze
maze = [
    ['S', '.', '.', '.', '.', '.', '#', '.', '.'],
    ['#', '#', '#', '#', '#', '.', '#', '#', '#'],
    ['.', '.', '.', '.', '.', '.', '.', '.', 'G'],
    ['#', '#', '#', '#', '#', '#', '#', '#', '#']
]

# Starting and goal positions
start_position = (2, 2)
goal_position = (1, 5)

# Solve the maze using DFS
result = dfs_maze(maze, start_position, goal_position)

# Print the maze with the path
for row in maze:
    print(' '.join(row))
print(result)
# Out:
# S . . . . . # . .
# # # # # # . # # #
# . . * * * * . . G
# # # # # # # # # #
# Path found

# %%
#Change the maze map to make it much larger then repeat the comparison.

import time
from collections import deque

def dfs_maze(maze, start, goal):
    rows, cols = len(maze), len(maze[0])
    visited = set()
    path = []  # Store the path
    
    def is_valid(x, y):
        return 0 <= x < rows and 0 <= y < cols and maze[x][y] != '#' and (x, y) not in visited
    
    def dfs(x, y):
        if x == goal[0] and y == goal[1]:
            return True
        
        visited.add((x, y))
        path.append((x, y))
        
        # Define possible moves: up, down, left, right
        moves = [(0, 1), (1, 0), (0, -1), (-1, 0)]
        for dx, dy in moves:
            new_x, new_y = x + dx, y + dy
            if is_valid(new_x, new_y):
                if dfs(new_x, new_y):
                    return True
        
        path.pop()  # Remove the current cell from the path if no valid moves
        return False
    
    if dfs(start[0], start[1]):
        # Update the maze with the path
        for x, y in path:
            if maze[x][y] != 'S' and maze[x][y] != 'G':
                maze[x][y] = '*'
        return "Path found"
    else:
        return "No path found"

def bfs_maze(maze, start, goal):
    rows, cols = len(maze), len(maze[0])
    queue = deque([start])
    visited = set([start])
    parent = {start: None}
    
    while queue:
        x, y = queue.popleft()
        
        if (x, y) == goal:
            break
        
        # Define possible moves: up, down, left, right
        moves = [(0, 1), (1, 0), (0, -1), (-1, 0)]
        for dx, dy in moves:
            new_x, new_y = x + dx, y + dy
            if 0 <= new_x < rows and 0 <= new_y < cols and maze[new_x][new_y] != '#' and (new_x, new_y) not in visited:
                queue.append((new_x, new_y))
                visited.add((new_x, new_y))
                parent[(new_x, new_y)] = (x, y)
    
    # Reconstruct the path
    if goal not in parent:
        return "No path found"
    
    path = []
    step = goal
    while step is not None:
        path.append(step)
        step = parent[step]
    
    path.reverse()
    
    # Update the maze with the path
    for x, y in path:
        if maze[x][y] != 'S' and maze[x][y] != 'G':
            maze[x][y] = '*'
    
    return "Path found"

# Define a larger maze
maze = [
    ['#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#'],
    ['#', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']]

# %%
# Define start and goal positions
start = (1, 1)
goal = (39, 34)

# Create a copy of the maze for each algorithm to use
maze_dfs = [row[:] for row in maze]
maze_bfs = [row[:] for row in maze]

# Perform DFS and measure the time taken
start_time = time.time()
dfs_result = dfs_maze(maze_dfs, start, goal)
dfs_time = time.time() - start_time

# Perform BFS and measure the time taken
start_time = time.time()
bfs_result = bfs_maze(maze_bfs, start, goal)
bfs_time = time.time() - start_time

# Print results
print("DFS Result:", dfs_result)
print("DFS Path:")
for row in maze_dfs:
    print(' '.join(row))

print("\nBFS Result:", bfs_result)
print("BFS Path:")
for row in maze_bfs:
    print(' '.join(row))

print("\nDFS Time:", dfs_time)
print("BFS Time:", bfs_time)
# Out:
# DFS Result: No path found
# DFS Path:
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# # . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#
# BFS Result: No path found
# BFS Path:
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# # . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#
# DFS Time: 0.0
# BFS Time: 0.0
